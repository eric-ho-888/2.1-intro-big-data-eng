# %%
"""Basic connection example.
"""

import redis

r = redis.Redis(
    host='skilled-microcool-slip-19495.db.redis.io',
    port=17946,
    decode_responses=True,
    username="default",
    password="KoKScbOo6pMFPryrEh9yfjMi700H3OaF",
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar
